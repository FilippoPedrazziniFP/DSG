# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
CUSTOMER_DATA = "../data/Customer.csv"

# %%
df_customer = pd.read_csv(CUSTOMER_DATA)
df_customer.columns
# Out:
# Index(['CustomerIdx', 'Sector', 'Subsector', 'Region', 'Country'], dtype='object')

# %%
print("Overview")
print(df_customer.head(5))
print(df_customer.describe())
# Out:
# Overview
#    CustomerIdx                        Sector                      Subsector  \
# 0         2975      Banks and Intermediaries                           Bank
# 1         1594  Asset Managers & Hedge Funds                            NaN
# 2          399                   Corporation  Corp - Comm. & Prof. Services
# 3          836                  Asset Owners                      Insurance
# 4          816                  Asset Owners                      Insurance
#
#      Region   Country
# 0  Americas  BARBADOS
# 1  Americas   BERMUDA
# 2  Americas   BERMUDA
# 3  Americas   BERMUDA
# 4  Americas   BERMUDA
#        CustomerIdx
# count  3471.000000
# mean   1735.000000
# std    1002.135719
# min       0.000000
# 25%     867.500000
# 50%    1735.000000
# 75%    2602.500000
# max    3470.000000

# %%
print()
print("Nan Values")
print(df_customer.isnull().sum())
# Out:
# Nan Values
# CustomerIdx      0
# Sector           0
# Subsector      352
# Region           0
# Country          0
# dtype: int64

# %%
print("Unique Sector Values")
print(df_customer['Sector'].nunique())

print()
print("Unique Subsector Values")
print(df_customer['Subsector'].nunique())

print()
print("Unique Region Values")
print(df_customer['Region'].nunique())

print()
print("Unique Country Values")
print(df_customer['Country'].nunique())
# Out:
# Unique Sector Values
# 5
#
# Unique Subsector Values
# 41
#
# Unique Region Values
# 3
#
# Unique Country Values
# 99

# %%
df_customer["Sector"].value_counts().plot(kind='bar')

# %%
df_customer["Subsector"].value_counts().plot(kind='bar')

# %%
df_customer["Region"].value_counts().plot(kind='bar')

# %%
df_customer["Country"].value_counts().plot(kind='bar')
