# %%
# %matplotlib inline
import pandas as pd
import matplotlib
import numpy as np
import matplotlib.pyplot as plt
ISIN_DATA = "../data/Isin.csv"

# %%
df_bonds = pd.read_csv(ISIN_DATA)
df_bonds.columns
# Out:
# Index(['IsinIdx', 'TickerIdx', 'ActualMaturityDateKey', 'IssueDateKey',
#        'Seniority', 'Currency', 'ActivityGroup', 'Region', 'Activity',
#        'RiskCaptain', 'Owner', 'CompositeRating', 'IndustrySector',
#        'IndustrySubgroup', 'MarketIssue', 'IssuedAmount', 'CouponType'],
#       dtype='object')

# %%
print("Overview")
print(df_bonds.head(5))
print(df_bonds.describe())
# Out:
# Overview
#    IsinIdx  TickerIdx  ActualMaturityDateKey  IssueDateKey Seniority Currency  \
# 0        0        238               20381231      20051129       GOV      USD
# 1        1        238               20331231      20051129       GOV      USD
# 2        2        238               20331231      20051129       GOV      ARS
# 3        3        236               20170417      20070417       GOV      USD
# 4        4        234               20221004      20100222       GOV      ARS
#
#        ActivityGroup    Region   Activity RiskCaptain          Owner  \
# 0  FLOW LOCAL MARKET  AMERICAS  ARGENTINA   ARGENTINA  EMK ARGENTINA
# 1  FLOW LOCAL MARKET  AMERICAS  ARGENTINA   ARGENTINA  EMK ARGENTINA
# 2  FLOW LOCAL MARKET  AMERICAS  ARGENTINA   ARGENTINA  EMK ARGENTINA
# 3  FLOW LOCAL MARKET  AMERICAS  ARGENTINA   ARGENTINA  EMK ARGENTINA
# 4  FLOW LOCAL MARKET  AMERICAS  ARGENTINA   ARGENTINA  EMK ARGENTINA
#
# ...

# %%
print("Nan Values")
print(df_bonds.isnull().sum())
# Out:
# Nan Values
# IsinIdx                   0
# TickerIdx                 0
# ActualMaturityDateKey     0
# IssueDateKey              0
# Seniority                 0
# Currency                  0
# ActivityGroup             0
# Region                    0
# Activity                  0
# RiskCaptain               0
# Owner                     0
# CompositeRating           0
# IndustrySector            5
# IndustrySubgroup          5
# MarketIssue              17
# IssuedAmount              0
# CouponType                0
# dtype: int64

# %%
print("Unique Seniority")
print(df_bonds['Seniority'].nunique())

print()
print("Unique Currency")
print(df_bonds['Currency'].nunique())

print()
print("Unique Activity Group")
print(df_bonds['ActivityGroup'].nunique())

print()
print("Unique Region")
print(df_bonds['Region'].nunique())

print()
print("Unique Activity")
print(df_bonds['Activity'].nunique())

print()
print("Unique Risk Captain")
print(df_bonds['RiskCaptain'].nunique())

print()
print("Unique Owner")
print(df_bonds['Owner'].nunique())

print()
print("Unique Composite Rating")
print(df_bonds['CompositeRating'].nunique())

print()
print("Unique Industry Sector")
print(df_bonds['IndustrySector'].nunique())

print()
print("Unique Industry Subgroup")
print(df_bonds['IndustrySubgroup'].nunique())

print()
print("Unique Market Issue")
print(df_bonds['MarketIssue'].nunique())

print()
print("Unique Coupon Type")
print(df_bonds['CouponType'].nunique())
# Out:
# Unique Seniority
# 9
#
# Unique Currency
# 23
#
# Unique Activity Group
# 3
#
# Unique Region
# 8
#
# Unique Activity
# 16
#
# Unique Risk Captain
# 38
#
# Unique Owner
# 105
#
# Unique Composite Rating
# 29
#
# Unique Industry Sector
# 13
#
# Unique Industry Subgroup
# 338
#
# Unique Market Issue
# 14
#
# Unique Coupon Type
# 6

# %%
df_bonds["Seniority"].value_counts().plot(kind='bar')

# %%
df_bonds["Currency"].value_counts().plot(kind='bar')

# %%
df_bonds["ActivityGroup"].value_counts().plot(kind='bar')

# %%
df_bonds["Region"].value_counts().plot(kind='bar')

# %%
df_bonds["Owner"].value_counts().plot(kind='bar')

# %%
df_bonds["IndustrySubgroup"].value_counts().plot(kind='bar')

# %%
df_bonds["IndustrySector"].value_counts().plot(kind='bar')
